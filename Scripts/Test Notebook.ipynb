# %%
from torch.utils.data import DataLoader
from DataLoader import ship_dataset, init_dataloader
from Models import *
from TrainingModel import ship_training_app
from collections import namedtuple
from multiprocessing import Process

data_params = namedtuple(
    'data_params',
    'root_dir, dataset, use_gpu, num_workers, batch_size',
)

model_params = namedtuple(
    'model_params',
    'name, opt_name, gpu, aug_model_name, epochs, valid_epochs, embeding_scale, number_of_embedings, ',
)

model_params_att = namedtuple(
    'model_params_att',
    'name, opt_name, gpu, aug_model_name, epochs, valid_epochs, blocks, heads, emb_scale, num_emb, heads_shape',
)

model_params_att_train = model_params_att("ATT_NN", ) 
number_of_blocks = 1, number_of_heads=4, embeding_scale = 30, 
                number_of_embedings = 128, head_neurons = [4096, 4096, 2048, 512, 1]

data_params_train = data_params("/home/franko/Desktop/DSelimovcProject/Dataset/", 'train', True, 2 ,32)
data_params_valid = data_params("/home/franko/Desktop/DSelimovcProject/Dataset/", 'valid', True, 1 ,32)
dl_train = init_dataloader(data_params_train)
dl_valid = init_dataloader(data_params_valid)

model = ATT_NN(number_of_blocks = 3, number_of_heads = 4, embeding_scale = 50, number_of_embedings = 64)

for batch in dl_train:
    input_data, output_data, info = batch
    print(input_data.shape)
    out = model(input_data)
    print(out.shape)
    break
print(output_data.shape)
# Out:
# torch.Size([32, 1, 3, 1501])
# torch.Size([32, 64, 1, 1452])
# torch.Size([32, 3])
# torch.Size([32, 3])

# %%
from torchsummary import summary
model.to('cuda')
summary(model, (1,3,1501), batch_size=-1)
# Out:
# torch.Size([2, 64, 1, 1452])
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [-1, 64, 1, 1452]           9,664
#            Dropout-2                [-1, 2, 64]               0
# Positional_Encoding-3                [-1, 2, 64]               0
# MultiheadAttention-4  [[-1, 2, 64], [-1, 1452, 1452]]               0
# Normalization_block-5                [-1, 2, 64]              64
# MultiheadAttention-6  [[-1, 2, 64], [-1, 1452, 1452]]               0
# Normalization_block-7                [-1, 2, 64]              64
#    Attention_block-8                [-1, 2, 64]               0
# MultiheadAttention-9  [[-1, 2, 64], [-1, 1452, 1452]]               0
# Normalization_block-10                [-1, 2, 64]              64
# MultiheadAttention-11  [[-1, 2, 64], [-1, 1452, 1452]]               0
# Normalization_block-12                [-1, 2, 64]              64
#   Attention_block-13                [-1, 2, 64]               0
# MultiheadAttention-14  [[-1, 2, 64], [-1, 1452, 1452]]               0
# Normalization_block-15                [-1, 2, 64]              64
# MultiheadAttention-16  [[-1, 2, 64], [-1, 1452, 1452]]               0
# Normalization_block-17                [-1, 2, 64]              64
#   Attention_block-18                [-1, 2, 64]               0
#            Linear-19                 [-1, 4096]     380,637,184
#              ReLU-20                 [-1, 4096]               0
#       BatchNorm1d-21                 [-1, 4096]           8,192
#           Dropout-22                 [-1, 4096]               0
#            Linear-23                 [-1, 4096]      16,781,312
#              ReLU-24                 [-1, 4096]               0
#       BatchNorm1d-25                 [-1, 4096]           8,192
#           Dropout-26                 [-1, 4096]               0
#            Linear-27                 [-1, 2048]       8,390,656
#              ReLU-28                 [-1, 2048]               0
#       BatchNorm1d-29                 [-1, 2048]           4,096
#           Dropout-30                 [-1, 2048]               0
#            Linear-31                  [-1, 512]       1,049,088
#              ReLU-32                  [-1, 512]               0
#       BatchNorm1d-33                  [-1, 512]           1,024
#           Dropout-34                  [-1, 512]               0
#            Linear-35                    [-1, 1]             513
#           Sigmoid-36                    [-1, 1]               0
#        head_block-37                    [-1, 1]               0
#            Linear-38                 [-1, 4096]     380,637,184
#              ReLU-39                 [-1, 4096]               0
#       BatchNorm1d-40                 [-1, 4096]           8,192
#           Dropout-41                 [-1, 4096]               0
#            Linear-42                 [-1, 4096]      16,781,312
#              ReLU-43                 [-1, 4096]               0
#       BatchNorm1d-44                 [-1, 4096]           8,192
#           Dropout-45                 [-1, 4096]               0
#            Linear-46                 [-1, 2048]       8,390,656
#              ReLU-47                 [-1, 2048]               0
#       BatchNorm1d-48                 [-1, 2048]           4,096
#           Dropout-49                 [-1, 2048]               0
#            Linear-50                  [-1, 512]       1,049,088
#              ReLU-51                  [-1, 512]               0
#       BatchNorm1d-52                  [-1, 512]           1,024
#           Dropout-53                  [-1, 512]               0
#            Linear-54                    [-1, 1]             513
#           Sigmoid-55                    [-1, 1]               0
#        head_block-56                    [-1, 1]               0
#            Linear-57                 [-1, 4096]     380,637,184
#              ReLU-58                 [-1, 4096]               0
#       BatchNorm1d-59                 [-1, 4096]           8,192
#           Dropout-60                 [-1, 4096]               0
#            Linear-61                 [-1, 4096]      16,781,312
#              ReLU-62                 [-1, 4096]               0
#       BatchNorm1d-63                 [-1, 4096]           8,192
#           Dropout-64                 [-1, 4096]               0
#            Linear-65                 [-1, 2048]       8,390,656
#              ReLU-66                 [-1, 2048]               0
#       BatchNorm1d-67                 [-1, 2048]           4,096
#           Dropout-68                 [-1, 2048]               0
#            Linear-69                  [-1, 512]       1,049,088
#              ReLU-70                  [-1, 512]               0
#       BatchNorm1d-71                  [-1, 512]           1,024
#           Dropout-72                  [-1, 512]               0
#            Linear-73                    [-1, 1]             513
#           Sigmoid-74                    [-1, 1]               0
#        head_block-75                    [-1, 1]               0
# ================================================================
# Total params: 1,220,650,819
# Trainable params: 1,220,650,435
# Non-trainable params: 384
# ----------------------------------------------------------------
# Input size (MB): 0.02
# Forward/backward pass size (MB): 12351.64
# Params size (MB): 4656.41
# Estimated Total Size (MB): 17008.07
# ----------------------------------------------------------------
